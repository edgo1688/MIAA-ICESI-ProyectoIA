# %% [markdown]
# # Plan de Trabajo - Tamizaje Automatizado de Glaucoma con Inteligencia Artificial
#
# ## Calendario General Proyecto
# - **Primera Etapa**: 7 de abril - 30 de abril (Entrega: 30 de abril)
# - **Segunda Etapa**: 1 de mayo - 30 de mayo (Entrega: 30 de mayo)
# - **Etapa Final**: 31 de mayo - 25 de junio (Entrega y presentación: 26 de junio)
#
# ---
#
# # Primera Etapa (7 de abril - 30 de abril)
#
# ## Objetivo:
# Configurar el proyecto y sentar las bases conceptuales y técnicas para el desarrollo.
#
# ### Tareas
#
# #### 7 - 10 de abril
# - [ ] **Configuración del Repositorio Git** (Responsable: Edwin)
#   Crear repositorio, definir estructura de carpetas y permisos de acceso para el equipo.
#
# #### 7 - 15 de abril
# - [ ] **Análisis del Problema** (Responsable: Equipo completo)
#   Definir claramente el problema que se desea resolver con IA.
#
# #### 10 - 15 de abril
# - [ ] **Árbol de Problemas** (Responsable: Edwin)
#   Elaborar un diagrama que muestre causas y consecuencias del problema.
#
# #### 10 - 17 de abril
# - [ ] **Definición de Objetivos SMART** (Responsable: Josué)
#   Redactar objetivos específicos, medibles, alcanzables, relevantes y con tiempo definido.
#
# #### 10 - 20 de abril
# - [ ] **Estado del Arte** (Responsables: Josué y Sebastián)
#   Investigar y resumir trabajos previos sobre tamizaje de glaucoma con IA.
#
# #### 17 - 20 de abril
# - [ ] **Planeación y Asignación de Tareas** (Responsable: Lina)
#   Crear un documento de planificación detallada con responsables.
#
# #### 17 - 30 de abril
# - [ ] **Análisis Exploratorio de Datos (EDA)** (Responsable: Equipo completo)
#
#
# ---
#
# # Segunda Etapa (1 de mayo - 30 de mayo)
#
# ## Objetivo:
# Desarrollar experimentos y modelado inicial para comprobar hipótesis.
#
# ### Tareas
#
# #### 1 - 7 de mayo
# - [ ] **Revisión y Corrección del EDA** (Responsable: Equipo completo)
#   Verificar la calidad del análisis exploratorio y corregir inconsistencias.
#
# #### 8 - 15 de mayo
# - [ ] **Desarrollo de Modelos de Referencia** (Responsables: Cada miembro con su modelo)
#   Implementar modelos base (pueden ser CNN básicas, VGG, ResNet, etc.).
#
# #### 16 - 25 de mayo
# - [ ] **Ejecución de Experimentos** (Responsable: Equipo completo)
#   Diseñar y correr experimentos para probar hipótesis planteadas, usando los modelos de referencia.
#
# #### 26 - 30 de mayo
# - [ ] **Análisis de Resultados de los Experimentos**
#   Interpretar resultados y preparar mini-reportes para etapa final.
#
# ---
#
# # Etapa Final (31 de mayo - 25 de junio)
#
# ## Objetivo:
# Consolidar resultados, elaborar el artículo final, producir el video y preparar la presentación.
#
# ### Tareas
#
# #### 31 de mayo - 10 de junio
# - [ ] **Redacción del Reporte Final (Artículo científico)** (Responsable: Equipo completo)
#   - Introducción
#   - Metodología
#   - Resultados
#   - Discusión
#   - Conclusiones
#   - Referencias
#
# #### 10 - 15 de junio
# - [ ] **Guión para Video Explicativo (10 minutos)**
#   Elaborar un guión breve y explicativo de todo el proyecto.
#
# #### 15 - 22 de junio
# - [ ] **Producción y Edición del Video**
#   Grabar, editar y finalizar video de presentación.
#
# #### 15 - 22 de junio
# - [ ] **Organización y Pulido del Notebook Final**
#   - Integrar códigos, análisis y resultados bien documentados.
#   - Formateo final en Markdown.
#
# #### 22 - 25 de junio
# - [ ] **Preparación de la Presentación Final**
#   Revisión de nuestro trabajo y aprobación del equipo para realizar entrega
#
# #### 26 de junio
# - [ ] **Entrega y Presentación del Proyecto en Clase**
#
# ---
